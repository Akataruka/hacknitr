# %% [markdown]
# # Importing Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
from sklearn.model_selection import train_test_split
import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D

# %% [markdown]
# # Import Data

# %%
import pandas as pd
data = pd.read_csv('./hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
x.shape
# Out:
# (10015, 2352)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
tabular_data = pd.read_csv('./HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'), 1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  3: ('df', 'dermatofibroma')}

# %% [markdown]
# # Frequency Distribution of Classes

# %%
sns.countplot(x = 'dx', data = tabular_data)
plt.xlabel('Disease', size=12)
plt.ylabel('Frequency', size=12)
plt.title('Frequency Distribution of Classes', size=16)
# Out:
# Text(0.5, 1.0, 'Frequency Distribution of Classes')

# %% [markdown]
# # Distribution of Disease over Gender

# %%
bar, ax = plt.subplots(figsize = (10,10))
plt.pie(tabular_data['sex'].value_counts(), labels = tabular_data['sex'].value_counts().index, autopct="%.1f%%")
plt.title('Gender of Patient', size=16)
# Out:
# Text(0.5, 1.0, 'Gender of Patient')

# %% [markdown]
# # Histogram of Age of Patients

# %%
bar, ax = plt.subplots(figsize=(10,10))
sns.histplot(tabular_data['age'])
plt.title('Histogram of Age of Patients', size=16)
# Out:
# Text(0.5, 1.0, 'Histogram of Age of Patients')

# %% [markdown]
# # Location of disease over Gender

# %%
value = tabular_data[['localization', 'sex']].value_counts().to_frame()
value.reset_index(level=[1,0 ], inplace=True)
temp = value.rename(columns = {'localization':'location', 0: 'count'})

bar, ax = plt.subplots(figsize = (12, 12))
sns.barplot(x = 'location',  y='count', hue = 'sex', data = temp)
plt.title('Location of disease over Gender', size = 16)
plt.xlabel('Disease', size=12)
plt.ylabel('Frequency/Count', size=12)
plt.xticks(rotation = 90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 value = tabular_data[['localization', 'sex']].value_counts().to_frame()
#       2 value.reset_index(level=[1,0 ], inplace=True)
#       3 temp = value.rename(columns = {'localization':'location', 0: 'count'})
#
# NameError: name 'tabular_data' is not defined

# %% [markdown]
# # Oversampling
# **To overcome class imbalace**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(46935,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %% [markdown]
# # Standardization and Splitting Data

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# # Model Training

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size = (3,3), input_shape = (28, 28, 3), activation = 'relu', padding = 'same'))
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model.add(Conv2D(64, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2), padding = 'same'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 26, 26, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 13, 13, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 182,663 (713.53 KB)
#  Trainable params: 182,663 (713.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.keras',
                                                  monitor='val_acc', mode='max',
                                                 verbose=1)

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer = 'adam',
              metrics = ['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 20,
                    callbacks=[callback])
# Out:
# Epoch 1/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4055 - loss: 1.5034
# Epoch 1: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - accuracy: 0.4065 - loss: 1.5010 - val_accuracy: 0.6897 - val_loss: 0.8247
# Epoch 2/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7363 - loss: 0.7169
# Epoch 2: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.7366 - loss: 0.7162 - val_accuracy: 0.8011 - val_loss: 0.5199
# Epoch 3/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8430 - loss: 0.4304
# Epoch 3: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.8431 - loss: 0.4302 - val_accuracy: 0.8639 - val_loss: 0.3948
# Epoch 4/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8935 - loss: 0.2915
# Epoch 4: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.8935 - loss: 0.2914 - val_accuracy: 0.8991 - val_loss: 0.2908
# Epoch 5/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9242 - loss: 0.2169
# Epoch 5: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9242 - loss: 0.2169 - val_accuracy: 0.9284 - val_loss: 0.2105
# Epoch 6/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9446 - loss: 0.1616
# Epoch 6: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9446 - loss: 0.1616 - val_accuracy: 0.9382 - val_loss: 0.1992
# Epoch 7/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9576 - loss: 0.1242
# Epoch 7: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9576 - loss: 0.1242 - val_accuracy: 0.9449 - val_loss: 0.1668
# Epoch 8/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9709 - loss: 0.0861
# Epoch 8: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9708 - loss: 0.0861 - val_accuracy: 0.9342 - val_loss: 0.2024
# Epoch 9/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9700 - loss: 0.0869
# Epoch 9: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.9700 - loss: 0.0869 - val_accuracy: 0.9537 - val_loss: 0.1507
# Epoch 10/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9783 - loss: 0.0594
# Epoch 10: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9783 - loss: 0.0594 - val_accuracy: 0.9449 - val_loss: 0.1780
# Epoch 11/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9737 - loss: 0.0767
# Epoch 11: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9736 - loss: 0.0767 - val_accuracy: 0.9586 - val_loss: 0.1498
# Epoch 12/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9842 - loss: 0.0459
# Epoch 12: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9842 - loss: 0.0460 - val_accuracy: 0.9647 - val_loss: 0.1388
# Epoch 13/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9891 - loss: 0.0341
# Epoch 13: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9891 - loss: 0.0342 - val_accuracy: 0.9611 - val_loss: 0.1504
# Epoch 14/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9871 - loss: 0.0390
# Epoch 14: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9871 - loss: 0.0393 - val_accuracy: 0.9454 - val_loss: 0.1982
# Epoch 15/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9863 - loss: 0.0386
# Epoch 15: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9864 - loss: 0.0386 - val_accuracy: 0.9694 - val_loss: 0.1349
# Epoch 16/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9913 - loss: 0.0260
# Epoch 16: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9912 - loss: 0.0260 - val_accuracy: 0.9575 - val_loss: 0.1948
# Epoch 17/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9933 - loss: 0.0214
# Epoch 17: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.9933 - loss: 0.0214 - val_accuracy: 0.9708 - val_loss: 0.1413
# Epoch 18/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9965 - loss: 0.0124
# Epoch 18: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.9964 - loss: 0.0127 - val_accuracy: 0.8569 - val_loss: 0.5054
# Epoch 19/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9681 - loss: 0.0932
# Epoch 19: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.9682 - loss: 0.0929 - val_accuracy: 0.9678 - val_loss: 0.1432
# Epoch 20/20
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9947 - loss: 0.0177
# Epoch 20: saving model to best_model.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9947 - loss: 0.0177 - val_accuracy: 0.9690 - val_loss: 0.1636

# %% [markdown]
# # Plot Accuracy and Loss

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import pickle

# save the iris classification model as a pickle file
model_pkl_file = "skin_disease_classifier_model.pkl"  

with open(model_pkl_file, 'wb') as file:  
    pickle.dump(model, file)

# %% [markdown]
# # Model Testing

# %%
loss, acc = model.evaluate(X_test, Y_test, verbose=2)
# Out:
# 294/294 - 2s - loss: 0.2400 - accuracy: 0.9455 - 2s/epoch - 6ms/step

# %%
X_test[0].shape
# Out:
# (28, 28, 3)

# %%
srcdir = './HAM10000_images_part_1'
count=0
for temp in os.listdir(srcdir):
    img = cv2.imread(os.path.join(srcdir, temp))
    cv2.imwrite(temp, img)
    img = cv2.resize(img, (28, 28))
    result = model.predict(img.reshape(1, 28, 28, 3))
    max_prob = max(result[0])
    class_ind = list(result[0]).index(max_prob)
    class_name = classes[class_ind]
    print(class_name)
    count+=1
    if count>10:
        break
# Out:
# 1/1 [==============================] - 0s 169ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 30ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 38ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 33ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 29ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 34ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 33ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 28ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 31ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 31ms/step
# ('nv', ' melanocytic nevi')
# 1/1 [==============================] - 0s 30ms/step
# ('nv', ' melanocytic nevi')

# %%
result = model.predict(X_test[0].reshape(1,28,28,3))
plt.imshow(X_test[0])
max_prob = max(result[0])
class_ind = list(result[0]).index(max_prob)
class_name = classes[class_ind]
print(class_name)
# Out:
# 1/1 [==============================] - 0s 128ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ('vasc', ' pyogenic granulomas and hemorrhage')

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.save('model.h5')
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
# Saving model structure to a YAML file 
model_yaml = model.to_yaml()  
with open("network.yaml", "w") as yaml_file: 
    yaml_file.write(model_yaml) 
  
# Saving weights of the model to a HDF5 file 
model.save_weights("network.h5")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Saving model structure to a YAML file
# ----> 2 model_yaml = model.to_yaml()
#       3 with open("network.yaml", "w") as yaml_file:
#       4     yaml_file.write(model_yaml)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3405, in Model.to_yaml(self, **kwargs)
#    3382 def to_yaml(self, **kwargs):
#    3383     """Returns a yaml string containing the network configuration.
#    3384
#    3385     Note: Since TF 2.6, this method is no longer supported and will raise a
#    (...)
#    3403         RuntimeError: announces that the method poses a security risk
#    3404     """
# -> 3405     raise RuntimeError(
#    3406         "Method `model.to_yaml()` has been removed due to security risk of "
#    3407         "arbitrary code execution. Please use `model.to_json()` instead."
#    3408     )
#
# RuntimeError: Method `model.to_yaml()` has been removed due to security risk of arbitrary code execution. Please use `model.to_json()` instead.

# %%
model.save("E:\\3\\model.keras")
